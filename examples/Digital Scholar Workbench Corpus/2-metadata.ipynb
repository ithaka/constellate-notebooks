# %% [markdown]
# ## Explore metadata for a curated collection
#
# This notebook shows how to connect to a curated TDM dataset and explore the metadata.

# %%
import pandas as pd

from tdm_core.client import Dataset

# %% [markdown]
# Initialize a TDM dataset object with the dataset ID provided in the email you received after curating your dataset in the Digital Scholars Workbench.

# %%
dset = Dataset('bb3d938b-bc61-4c2c-a21c-9a4f102035c8')

# %% [markdown]
# Find total number of documents in the dataset.

# %%
len(dset)
# Out:
# 61

# %% [markdown]
# After initializing the `Dataset`, the documents in the dataset are downloaded in the background.
#
# A list of all of the items in the Dataset is available.

# %%
dset.items[:5]
# Out:
# ['http://hdl.handle.net/2027/uc1.b4880650',
#  'http://hdl.handle.net/2027/mdp.39076006733898',
#  'http://hdl.handle.net/2027/uc1.32106002083555',
#  'http://hdl.handle.net/2027/uva.x000926626',
#  'http://hdl.handle.net/2027/nyp.33433082396866']

# %% [markdown]
# An individual document can be downloaded by calling the `.get` method.

# %%
doc = dset.get(dset.items[50])

# %% [markdown]
# Iterate through the metdata and caputure title and publication date.

# %%
rows = []
for d in docs:
    if d == {}:
        continue
    meta = d.get('metadata')
    if meta is None:
        continue
    if isinstance(meta, list):
        meta = [m for m in meta if m['@type'] == 'PublicationIssue'][0]
    yr = meta.get('pubDate') or meta['datePublished']['@value'][:4]
    decade = int(str(yr)[0:3] + '0')
    title = meta.get('title') or meta.get('name')
    pages = d['features']['pageCount']
    rows.append([
        meta.get('id') or d.get('id') or 'unknown', 
        d['creator']['name'],
        int(yr),
        decade,
        title,
        pages
        ])

# %%
df = pd.DataFrame(rows, columns=['id', 'provider', 'year', 'decade', 'title', 'pages'])

# %%
df
# Out:
#                                                    id  \
# 0             http://hdl.handle.net/2027/uc1.b4880650
# 1       http://hdl.handle.net/2027/mdp.39076006733898
# 2       http://hdl.handle.net/2027/uc1.32106002083555
# 3           http://hdl.handle.net/2027/uva.x000926626
# 4       http://hdl.handle.net/2027/nyp.33433082396866
# 5       http://hdl.handle.net/2027/mdp.39015030718087
# 6   http://hdl.handle.net/2027/uc2.ark:/13960/t1xd...
# 7       http://hdl.handle.net/2027/mdp.39015019763518
# 8       http://hdl.handle.net/2027/mdp.49015000556002
# 9       http://hdl.handle.net/2027/mdp.39015025045207
# 10  http://hdl.handle.net/2027/uc2.ark:/13960/fk2q...
# 11      http://hdl.handle.net/2027/mdp.39015059999972
# 12      http://hdl.handle.net/2027/mdp.39015030718079
# 13      http://hdl.handle.net/2027/mdp.39015014856416
# 14              http://www.jstor.org/stable/i26460624
# 15                http://www.jstor.org/stable/i301398
# 16              http://www.jstor.org/stable/i40038366
# 17              http://www.jstor.org/stable/i25118385
# 18                http://www.jstor.org/stable/i403422
# 19              http://www.jstor.org/stable/i25751528
# 20              http://www.jstor.org/stable/i23329232
# 21              http://www.jstor.org/stable/i20572102
# 22              http://www.jstor.org/stable/i40168263
# 23              http://www.jstor.org/stable/i20683816
# 24                http://www.jstor.org/stable/i219519
# 25              http://www.jstor.org/stable/i25120501
# 26              http://www.jstor.org/stable/i26106398
# 27              http://www.jstor.org/stable/i40168559
# 28              http://www.jstor.org/stable/i40107559
# 29              http://www.jstor.org/stable/i30030138
# 30                http://www.jstor.org/stable/i219573
# 31              http://www.jstor.org/stable/i26441175
# 32                http://www.jstor.org/stable/i347005
# 33                http://www.jstor.org/stable/i347091
# 34              http://www.jstor.org/stable/i26438866
# 35                http://www.jstor.org/stable/i403777
# 36              http://www.jstor.org/stable/i27532965
# 37              http://www.jstor.org/stable/i40136633
# 38                http://www.jstor.org/stable/i347051
# 39              http://www.jstor.org/stable/i25091409
# 40              http://www.jstor.org/stable/i27777757
# 41                http://www.jstor.org/stable/i347031
# 42              http://www.jstor.org/stable/i40027381
# 43              http://www.jstor.org/stable/i40023869
# 44              http://www.jstor.org/stable/i24413792
# 45              http://www.jstor.org/stable/i26365679
# 46                http://www.jstor.org/stable/i215497
# 47                http://www.jstor.org/stable/i347021
# 48                http://www.jstor.org/stable/i347132
# 49                http://www.jstor.org/stable/i347185
# 50                http://www.jstor.org/stable/i347113
# 51                http://www.jstor.org/stable/i347228
# 52              http://www.jstor.org/stable/i27706668
# 53              http://www.jstor.org/stable/i26366572
# 54              http://www.jstor.org/stable/i26366311
# 55              http://www.jstor.org/stable/i24483151
# 56                http://www.jstor.org/stable/i347257
# 57                http://www.jstor.org/stable/i347208
# 58              http://www.jstor.org/stable/i25790051
# 59                http://www.jstor.org/stable/i353128
#
#                       provider  year  decade  \
# 0   HathiTrust Research Center  1961    1960
# 1                      Portico  1945    1940
# 2                      Portico  1953    1950
# 3                      Portico  1956    1950
# 4                      Portico  1921    1920
# 5                      Portico  1921    1920
# 6                      Portico  1921    1920
# 7                      Portico  1949    1940
# 8                      Portico  1965    1960
# 9                      Portico  1949    1940
# 10  HathiTrust Research Center  1886    1880
# 11                     Portico  2003    2000
# 12  HathiTrust Research Center  1898    1890
# 13                     Portico  1948    1940
# 14                       JSTOR  1907    1900
# 15                       JSTOR  1949    1940
# 16                       JSTOR  1941    1940
# 17                       JSTOR  1884    1880
# 18                       JSTOR  1980    1980
# 19                       JSTOR  1900    1900
# 20                       JSTOR  1959    1950
# 21                       JSTOR  1919    1910
# 22                       JSTOR  1901    1900
# 23                       JSTOR  2008    2000
# 24                       JSTOR  1929    1920
# 25                       JSTOR  1920    1920
# 26                       JSTOR  2015    2010
# 27                       JSTOR  1904    1900
# 28                       JSTOR  1919    1910
# 29                       JSTOR  1997    1990
# 30                       JSTOR  1943    1940
# 31                       JSTOR  1955    1950
# 32                       JSTOR  1931    1930
# 33                       JSTOR  1952    1950
# 34                       JSTOR  2003    2000
# 35                       JSTOR  1993    1990
# 36                       JSTOR  1917    1910
# 37                       JSTOR  1995    1990
# 38                       JSTOR  1942    1940
# 39                       JSTOR  1998    1990
# 40                       JSTOR  1985    1980
# 41                       JSTOR  1937    1930
# 42                       JSTOR  1960    1960
# 43                       JSTOR  1982    1980
# 44                       JSTOR  2012    2010
# 45                       JSTOR  1981    1980
# 46                       JSTOR  1986    1980
# 47                       JSTOR  1935    1930
# 48                       JSTOR  1962    1960
# 49                       JSTOR  1976    1970
# 50                       JSTOR  1958    1950
# 51                       JSTOR  1986    1980
# 52                       JSTOR  1956    1950
# 53                       JSTOR  2005    2000
# 54                       JSTOR  2006    2000
# 55                       JSTOR  2013    2010
# 56                       JSTOR  1993    1990
# 57                       JSTOR  1981    1980
# 58                       JSTOR  2011    2010
# 59                       JSTOR  1961    1960
#
#                                                 title  pages
# 0                                       Walt Whitman.     56
# 1                                      Walt Whitman /    706
# 2                                       Walt Whitman,    706
# 3                          Walt Whitman, une étude /    262
# 4                      Walt Whitman in Mickle Street.    260
# 5                      Walt Whitman in Mickle Street.    260
# 6                      Walt Whitman in Mickle Street.    258
# 7   Faint clews & indirections : manuscripts of Wa...    272
# 8   Faint clews & indirections; manuscripts of Wal...    272
# 9   Faint clews & indirections : manuscripts of Wa...    272
# 10      Leaves of grass : the poems of Walt Whitman /    366
# 11  Visiting Walt : poems inspired by the life & w...    264
# 12  Diary notes of a visit to Walt Whitman and som...    188
# 13  Walt Whitman, une étude : un choix de poèmes p...    264
# 14  The Museum News (Brooklyn Institute of Arts an...      0
# 15            Comparative Literature volume 1 issue 3     99
# 16  The Yale University Library Gazette volume 15 ...     21
# 17     The North American Review volume 138 issue 331     99
# 18                 The Kenyon Review volume 2 issue 4    131
# 19  The Advocate of Peace (1894-1920) volume 62 is...     29
# 20                 Indian Literature volume 2 issue 2    200
# 21                           Poetry volume 14 issue 2     58
# 22  The Journal of Education volume 54 issue 11 (1...     13
# 23       The American Poetry Review volume 37 issue 3     78
# 24                             PMLA volume 44 issue 4    320
# 25     The North American Review volume 211 issue 774    145
# 26                        The Powys Journal volume 25    248
# 27  The Journal of Education volume 60 issue 2 (1486)     14
# 28  The Journal of Education volume 89 issue 19 (2...     42
# 29                              ELH volume 64 issue 2    305
# 30                             PMLA volume 58 issue 4    312
# 31    The Virginia Quarterly Review volume 31 issue 4    195
# 32               American Literature volume 2 issue 4    132
# 33              American Literature volume 24 issue 2    160
# 34    The Virginia Quarterly Review volume 79 issue 1    228
# 35                The Kenyon Review volume 15 issue 3    229
# 36               The Sewanee Review volume 25 issue 1    143
# 37                     Film Comment volume 31 issue 1     94
# 38              American Literature volume 14 issue 2    105
# 39         The Massachusetts Review volume 39 issue 2    159
# 40       The American Poetry Review volume 14 issue 5     75
# 41               American Literature volume 9 issue 2    181
# 42                 Prairie Schooner volume 34 issue 2    114
# 43                             Salmagundi issue 58/59    438
# 44       The North American Review volume 297 issue 2     72
# 45  Resources for American Literary Study volume 1...    184
# 46        The New England Quarterly volume 59 issue 4    183
# 47               American Literature volume 6 issue 4    108
# 48              American Literature volume 34 issue 3    158
# 49              American Literature volume 47 issue 4    153
# 50              American Literature volume 29 issue 4    154
# 51              American Literature volume 58 issue 3    192
# 52  The Journal of English and Germanic Philology ...    214
# 53    Resources for American Literary Study volume 30    414
# 54    Resources for American Literary Study volume 31    419
# 55             The English Journal volume 103 issue 2    127
# 56              American Literature volume 65 issue 4    263
# 57              American Literature volume 53 issue 3    252
# 58             The English Journal volume 100 issue 3    128
# 59            Modern Language Notes volume 76 issue 8    306

# %% [markdown]
# Year range of documents in this dataset

# %%
print('{} to {}'.format(df['year'].min(), df['year'].max()))
# Out:
# 1884 to 2015

# %% [markdown]
# Save the metadata as a CSV file for later use.

# %%
df.to_csv('metadata.csv')

# %% [markdown]
# Plot the number of volumes by decade in the sample set.

# %%
df.groupby(['decade', 'provider'])['id'].agg('count').unstack()\
    .plot.bar(title='Issues by decade', figsize=(20, 5), fontsize=12, stacked=True);

# %%
df.groupby(['decade', 'provider'])['pages'].agg('sum').unstack()\
    .plot.bar(title='Pages by decade', figsize=(20, 5), fontsize=12, stacked=True);
